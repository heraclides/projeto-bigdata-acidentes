# %%
df_bronze = spark.table(
    "projeto_profissional_big_data.datatran_2018.bronze_datatran18"
)

# %%
df_bronze.printSchema

# %%
df_bronze.show(5)

# %%
df_bronze.select(
    "id",
    "data_inversa",
    "municipio",
    "uf",
    "br",
    "km",
    "causa_acidente"
).show(10, truncate=False)
